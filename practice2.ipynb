# %%
students = { 
    "aarohan": 29, 
    "pratyush": 49,
    "aam": 100,
    "rita": 69,
}

# %%
highest_number = 0
for x in students:
    if (students[x] > highest_number) : 
        highest = x
        highest_number = students[x]

print ("Heighest Scorer",highest)
# Out:
# Heighest Scorer sam

# %%
toDelete = []
for x in students:
    if (students[x] < 50) : 
        toDelete.append (x)
    
for i in toDelete: 
    del students[i]
print (students)
# Out:
# {'sam': 100, 'rita': 69}

# %%
for k in students: 
    s = sorted(students.items(), key=lambda item:item[1], reverse=True)
print (s)
# Out:
# [('aam', 100), ('rita', 69), ('pratyush', 49), ('aarohan', 29)]
